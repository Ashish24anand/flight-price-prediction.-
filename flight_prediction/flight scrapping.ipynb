# %%
# Importing Libraries
import selenium
import pandas as pd
import time
#from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re
# importing keys
from selenium.webdriver.common.keys import Keys

from datetime import datetime

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the archive page of thehindu.in
url = "https://www.yatra.com/"
driver.get(url)

time.sleep(2)

# %%
df=pd.DataFrame()
date=[]
li=[' delhi',' mumbai',' bangalore',' pune',' chennai',' Hyderabad',' Ahmedabad',' Cochin',' Goa']
for i in li:
    li.remove(i)
    for j in li:
        
        driver.find_element_by_xpath('//li[@class="datepicker flex1"]').click()
        time.sleep(1)
        date1=driver.find_elements_by_xpath('//tbody[@class="BE_flight_origin_date"]//tr//td')
        for k in date1:
            if k.get_attribute('data-date') !=None and k.get_attribute('data-date') !="":
                date.append(k.get_attribute('data-date'))
        for k in date:
        
                origin=driver.find_element_by_xpath('//input[@class="required_field cityPadRight ac_input origin_ac"]')
                for car in i:
                    time.sleep(0.2)
                    origin.send_keys(car)
                origin.send_keys(Keys.ENTER)

                time.sleep(0.5)
                try:
                    dest=driver.find_element_by_xpath('//input[@class="required_field cityPadLeft ac_input dest_ac"]')
                except NoSuchElementException:
                    time.sleep(1)
                    dest=driver.find_element_by_xpath('//input[@class="required_field cityPadLeft ac_input dest_ac"]')
                for car in j:
                    time.sleep(0.2)
                    dest.send_keys(car)
                dest.send_keys(Keys.ENTER)
                time.sleep(0.5)
                try:
                    driver.find_element_by_xpath('//li[@class="datepicker flex1"]').click()
                except:
                    print('ok')
                time.sleep(0.5)
                driver.find_element_by_xpath(f'//td[@data-date="{k}"]').click()
                driver.find_element_by_xpath('//input[@class="js_ripple search-btn "]').click() #clicking search buttom 
                time.sleep(0.5)
                alpha=0
                while alpha<5:
                    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                    time.sleep(0.4)
                    alpha+=1
                stops=[i.text for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')]
                airline=[i.text for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')]                    
                city = [i.text for i in driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')]
                d_t=[i.text for i in driver.find_elements_by_xpath('//div[@class="i-b pr"]')]
                a_t=[i.text for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')]
                t_t=[i.text for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')]                    
                price=[i.text for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')]
                stops=[i.text for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')]
                date1=[k for i in range(len(price))]
                a=1
                destination=[]
                source=[]
                for l in city:
                    if a%2==0:
                        destination.append(l)
                    else:
                        source.append(l)
                    a+=1
                temp=pd.DataFrame()
                temp['airline']=airline
                temp['date']=date1
                temp['source']=source
                temp['destination']=destination
                temp['price']=price
                temp['d_t']=d_t
                temp['a_t']=a_t
                temp['t_t']=t_t
                temp['stops']=stops
                temp['price']=price
                
                df=pd.concat([df,temp],axis=0)
                url = "https://www.yatra.com/"
                driver.get(url)

                time.sleep(2)
# Out:
# ok
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-3-e1857ee54f9d> in <module>
#      41                 alpha=0
#      42                 while alpha<5:
# ---> 43                     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#      44                     time.sleep(0.4)
#      45                     alpha+=1
#
# ~\Anaconda3\envs\tensorflow_cpu\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~\Anaconda3\envs\tensorflow_cpu\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
def ind(l,a):
    for b in range(len(l)):
        if l[b] == a:
            break
    return b

# %%
li=[' delhi',' mumbai',' bangalore',' pune',' chennai',' Hyderabad',' Ahmedabad',' Cochin',' Goa']
li1=[' delhi',' mumbai',' bangalore',' pune',' chennai',' Hyderabad',' Ahmedabad',' Cochin',' Goa']

# %%
b1=list(df['date'])[-1]

# %%
b1='10/12/2021'

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the archive page of thehindu.in
url = "https://www.yatra.com/"
driver.get(url)

time.sleep(2)

# %%
#date_k=1
date_k=ind(date,b1)
counter=0
for i in li:
    li.remove(i)
    li1.remove(i)
    li1.remove(' mumbai')
    li1.remove(' bangalore')
    li1.remove(' pune')
    li1.remove(' chennai')
    li1.remove(' Hyderabad')
    for j in li1:
        li1.remove(j)
        for k in date[date_k:]:
            
                origin=driver.find_element_by_xpath('//input[@class="required_field cityPadRight ac_input origin_ac"]')
                for car in i:
                    time.sleep(0.2)
                    origin.send_keys(car)
                origin.send_keys(Keys.ENTER)
                time.sleep(0.5)
                try:
                    dest=driver.find_element_by_xpath('//input[@class="required_field cityPadLeft ac_input dest_ac"]')
                except NoSuchElementException:
                    time.sleep(1)
                    dest=driver.find_element_by_xpath('//input[@class="required_field cityPadLeft ac_input dest_ac"]')
                for car in j:
                    time.sleep(0.2)
                    dest.send_keys(car)
                dest.send_keys(Keys.ENTER)
                time.sleep(0.5)
                try:
                    driver.find_element_by_xpath('//li[@class="datepicker flex1"]').click()
                except:
                    print('ok')
                time.sleep(5)
                aaa=f'//td[@data-date="{k}"]'
                driver.find_element_by_xpath(aaa).click()
                driver.find_element_by_xpath('//input[@class="js_ripple search-btn "]').click() #clicking search buttom 
                time.sleep(0.5)
                alpha=0
                while alpha<5:
                    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                    time.sleep(0.4)
                    alpha+=1
                stops=[i.text for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')]
                airline=[i.text for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]')]                    
                city = [i.text for i in driver.find_elements_by_xpath('//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')]
                d_t=[i.text for i in driver.find_elements_by_xpath('//div[@class="i-b pr"]')]
                a_t=[i.text for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')]
                t_t=[i.text for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]')]                    
                price=[i.text for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')]
                stops=[i.text for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')]
                date1=[k for i in range(len(price))]
                a=1
                destination=[]
                source=[]
                for l in city:
                    if a%2==0:
                        destination.append(l)
                    else:
                        source.append(l)
                    a+=1
                temp=pd.DataFrame()
                temp['airline']=airline
                temp['date']=date1
                temp['source']=source
                temp['destination']=destination
                temp['price']=price
                temp['d_t']=d_t
                temp['a_t']=a_t
                temp['t_t']=t_t
                temp['stops']=stops
                temp['price']=price
                
                df=pd.concat([df,temp],axis=0)
                url = "https://www.yatra.com/"
                driver.get(url)

                time.sleep(2)
                counter+=1
                if counter > 30:
                    driver.quit()
                    time.sleep(2)
                    driver=webdriver.Chrome("chromedriver.exe") 
                    time.sleep(1)
                    # Opening the archive page of thehindu.in
                    url = "https://www.yatra.com/"
                    driver.get(url)
                    time.sleep(2)
                    counter = 0
# Out:
# ok
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-81-73e1b9250e9e> in <module>
#      36                 time.sleep(5)
#      37                 aaa=f'//td[@data-date="{k}"]'
# ---> 38                 driver.find_element_by_xpath(aaa).click()
#      39                 driver.find_element_by_xpath('//input[@class="js_ripple search-btn "]').click() #clicking search buttom
#      40                 time.sleep(0.5)
#
# ~\Anaconda3\envs\tensorflow_cpu\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\envs\tensorflow_cpu\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
# ...

# %%
driver.find_element_by_xpath(aaa).click()

# %%
aaa=f'//td[@data-date="{k}"]'

# %%
df
# Out:
#       airline        date     source destination  price    d_t  \
# 0    Go First  10/10/2021  New Delhi   Hyderabad  5,954  06:30
# 1    Go First  10/10/2021  New Delhi   Hyderabad  5,954  21:15
# 2    SpiceJet  10/10/2021  New Delhi   Hyderabad  5,955  21:00
# 3      IndiGo  10/10/2021  New Delhi   Hyderabad  5,955  22:00
# 4      IndiGo  10/10/2021  New Delhi   Hyderabad  5,955  07:10
# ..        ...         ...        ...         ...    ...    ...
# 41   SpiceJet  10/12/2021  New Delhi   Ahmedabad  6,106  18:45
# 42  Air India  10/12/2021  New Delhi   Ahmedabad  6,365  08:40
# 43  Air India  10/12/2021  New Delhi   Ahmedabad  6,890  16:00
# 44   SpiceJet  10/12/2021  New Delhi   Ahmedabad  7,004  07:00
# 45   SpiceJet  10/12/2021  New Delhi   Ahmedabad  7,004  18:10
#
#                a_t      t_t      stops
# 0            08:30   2h 00m   Non Stop
# 1            23:15   2h 00m   Non Stop
# 2            23:05   2h 05m   Non Stop
# 3   00:05\n+ 1 day   2h 05m   Non Stop
# ...

# %%
date
# Out:
# ['09/10/2021',
#  '10/10/2021',
#  '11/10/2021',
#  '12/10/2021',
#  '13/10/2021',
#  '14/10/2021',
#  '15/10/2021',
#  '16/10/2021',
#  '17/10/2021',
#  '18/10/2021',
#  '19/10/2021',
#  '20/10/2021',
#  '21/10/2021',
#  '22/10/2021',
#  '23/10/2021',
#  '24/10/2021',
#  '25/10/2021',
#  '26/10/2021',
#  '27/10/2021',
#  '28/10/2021',
#  '29/10/2021',
#  '30/10/2021',
#  '31/10/2021',
#  '01/11/2021',
#  '02/11/2021',
#  '03/11/2021',
#  '04/11/2021',
#  '05/11/2021',
#  '06/11/2021',
#  '07/11/2021',
#  '08/11/2021',
#  '09/11/2021',
#  '10/11/2021',
#  '11/11/2021',
#  '12/11/2021',
#  '13/11/2021',
#  '14/11/2021',
#  '15/11/2021',
#  '16/11/2021',
#  '17/11/2021',
#  '18/11/2021',
#  '19/11/2021',
#  '20/11/2021',
#  '21/11/2021',
#  '22/11/2021',
#  '23/11/2021',
#  '24/11/2021',
#  '25/11/2021',
#  '26/11/2021',
#  '27/11/2021',
#  '28/11/2021',
#  '29/11/2021',
#  '30/11/2021',
#  '01/12/2021',
#  '02/12/2021',
#  '03/12/2021',
#  '04/12/2021',
#  '05/12/2021',
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#       airline        date     source destination  price    d_t  \
# 0    Go First  10/10/2021  New Delhi   Hyderabad  5,954  06:30
# 1    Go First  10/10/2021  New Delhi   Hyderabad  5,954  21:15
# 2    SpiceJet  10/10/2021  New Delhi   Hyderabad  5,955  21:00
# 3      IndiGo  10/10/2021  New Delhi   Hyderabad  5,955  22:00
# 4      IndiGo  10/10/2021  New Delhi   Hyderabad  5,955  07:10
# ..        ...         ...        ...         ...    ...    ...
# 59  Air India  09/01/2022  New Delhi   Ahmedabad  7,273  09:45
# 60  Air India  09/01/2022  New Delhi   Ahmedabad  8,477  22:00
# 61  Air India  09/01/2022  New Delhi   Ahmedabad  8,477  10:55
# 63     IndiGo  09/01/2022  New Delhi   Ahmedabad  9,232  13:15
# 64     IndiGo  09/01/2022  New Delhi   Ahmedabad  9,232  08:00
#
#                a_t      t_t      stops
# 0            08:30   2h 00m   Non Stop
# 1            23:15   2h 00m   Non Stop
# 2            23:05   2h 05m   Non Stop
# 3   00:05\n+ 1 day   2h 05m   Non Stop
# ...

# %%
df.to_csv('airline1.csv')
